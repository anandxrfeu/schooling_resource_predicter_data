# %% [markdown]
# ## Population Size

# %% [markdown]
# ### Population size by municipality
#
# 1 Visit https://sidra.ibge.gov.br/tabela/6579
#
# 2 Select the year "from" which you want to pull out data
#
# 3 Select "município"option "for the "Unidade Territorial"session
#
# 4 Click Download
#
#     4.1 Select the format you want to download your file. Select "CSV US"
#
#     4.2 Include a name "for your file
#
#  5 Click Download

# %%
import pandas as pd

# %%
df = pd.read_csv("../raw_data/Population_Size.csv" ,sep=";")
df
# Out:
#                        Município          Ano        Ano.1        Ano.2  \
# 0                            NaN         2011         2012         2013
# 1     Alta Floresta D'Oeste (RO)      24.228       24.069       25.728
# 2                 Ariquemes (RO)      91.570       92.747      101.269
# 3                    Cabixi (RO)       6.221        6.132        6.495
# 4                    Cacoal (RO)      78.959       79.330       85.863
# ...                          ...          ...          ...          ...
# 5566             Vianópolis (GO)      12.644       12.737       13.227
# 5567         Vicentinópolis (GO)       7.476        7.576        7.933
# 5568               Vila Boa (GO)       4.847        4.954        5.246
# 5569          Vila Propício (GO)       5.196        5.244        5.460
# 5570               Brasília (DF)   2.609.998    2.648.532    2.789.761
#
#             Ano.3        Ano.4        Ano.5        Ano.6        Ano.7  \
# ...

# %% [markdown]
# ### Missing :
# -> calculate population Size growth rate YoY
#
# -> Export the cleaned and pivoted dataframe to CSV
