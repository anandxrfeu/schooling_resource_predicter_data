# %%
import pandas as pd

# %%
df = pd.read_csv('../raw_data/Unemployment/desocupacao.csv', sep=';')

# %%
df.head(10)
# Out:
#   Sigla  Codigo            Estado    2012   2013    2014    2015    2016  \
# 0    AC      12              Acre     8,4  8,975     7,7   8,475  10,875
# 1    AL      27           Alagoas   11,35   10,6   9,625    11,2  14,075
# 2    AM      13          Amazonas     9,5  9,075   7,725   9,525  13,575
# 3    AP      16             Amapá  13,225  11,45  10,325  11,025   15,45
# 4    BA      29             Bahia   11,05  11,15   10,25   12,25   15,85
# 5    CE      23             Ceará     7,7  7,825    7,35   8,825   11,95
# 6    DF      53  Distrito Federal   8,625  9,025    8,95    10,1      12
# 7    ES      32    Espírito Santo   7,125  7,125   6,175     7,7  12,225
# 8    GO      52             Goiás   5,375  5,425     5,3     7,3  10,475
# 9    MA      21          Maranhão    8,05   7,85   6,825   8,575   11,85
#
#      2017    2018    2019    2020    2021    2022
# 0  14,125  13,525    14,5  15,075  15,325    11,7
# 1  16,675      17    14,9  18,575   17,75  11,175
# ...
