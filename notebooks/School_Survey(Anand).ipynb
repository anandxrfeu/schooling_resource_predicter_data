# %% [markdown]
# # Matrículas

# %%
import pandas as pd

# %%
# Convert the corrected string to a DataFrame
df = pd.read_csv("../raw_data/teachers/docentes_2007.csv")
df
# Out:
#      Região Geográfica Unidade da Federação                 Município  \
# 0       Centro-Oeste     Distrito Federal                  Brasília
# 1       Centro-Oeste                Goiás             Vila Propício
# 2       Centro-Oeste                Goiás                  Vila Boa
# 3       Centro-Oeste                Goiás            Vicentinópolis
# 4       Centro-Oeste                Goiás                Vianópolis
# ...                ...                  ...                       ...
# 5560           Norte             Rondônia                Cerejeiras
# 5561           Norte             Rondônia                    Cacoal
# 5562           Norte             Rondônia                    Cabixi
# 5563           Norte             Rondônia                 Ariquemes
# 5564           Norte             Rondônia     Alta Floresta D'Oeste
#
#       Código do Município   Urbana  Rural
# 0                 5300108   2,749     99
# 1                 5222302      11      9
# 2                 5222203      17    -
# 3                 5222054      17    -
# 4                 5222005      18    -
# ...                   ...      ...    ...
# 5560              1100056      29    -
# 5561              1100049     169    -
# 5562              1100031      20    -
# 5563              1100023     121    -
# 5564              1100015      72    -
#
# [5565 rows x 6 columns]

# %%
# Melt the dataframe
melted_df = df.melt(id_vars=["Região Geográfica", "Unidade da Federação", "Município", "Código do Município"],
                                        value_vars=["Urbana", "Rural"],
                                        var_name="Rede",
                                        value_name="Docentes")

# Sort the dataframe for better visualization
melted_df = melted_df.sort_values(by=["Município", "Rede"]).reset_index(drop=True)

melted_df
# Out:
#       Região Geográfica Unidade da Federação               Município  \
# 0        Centro-Oeste                Goiás         Abadia de Goiás
# 1        Centro-Oeste                Goiás         Abadia de Goiás
# 2             Sudeste         Minas Gerais     Abadia dos Dourados
# 3             Sudeste         Minas Gerais     Abadia dos Dourados
# 4        Centro-Oeste                Goiás               Abadiânia
# ...                 ...                  ...                     ...
# 11125        Nordeste                Bahia           Érico Cardoso
# 11126           Norte                 Pará                  Óbidos
# 11127           Norte                 Pará                  Óbidos
# 11128         Sudeste            São Paulo                    Óleo
# 11129         Sudeste            São Paulo                    Óleo
#
#        Código do Município    Rede Docentes
# 0                  5200050   Rural     -
# 1                  5200050  Urbana      20
# 2                  3100104   Rural     -
# 3                  3100104  Urbana      19
# 4                  5200100   Rural     -
# ...                    ...     ...      ...
# 11125              2900504  Urbana      17
# 11126              1505106   Rural     -
# 11127              1505106  Urbana      49
# 11128              3533809   Rural     -
# 11129              3533809  Urbana      16
#
# [11130 rows x 6 columns]

# %%
df = pd.read_csv("../raw_data/teachers/docentes_2021.csv", sep=";")
df
# Out:
#              Unnamed: 0            Unnamed: 1                Unnamed: 2  \
# 0     Região Geográfica  Unidade da Federação                 Município
# 1                   NaN                   NaN                       NaN
# 2                   NaN                   NaN                       NaN
# 3                   NaN                   NaN                       NaN
# 4               Norte              Rondônia     Alta Floresta D'Oeste
# ...                 ...                   ...                       ...
# 5590                NaN                   NaN                       NaN
# 5591                NaN                   NaN                       NaN
# 5592                NaN                   NaN                       NaN
# 5593                NaN                   NaN                       NaN
# 5594                NaN                   NaN                       NaN
#
#                Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0     Código do Município     Urbana      Rural         NaN         NaN
# 1                     NaN        NaN        NaN         NaN         NaN
# 2                     NaN        NaN        NaN         NaN         NaN
# 3                     NaN        NaN        NaN         NaN         NaN
# 4                 1100015        70         28          NaN         NaN
# ...                   ...        ...        ...         ...         ...
# 5590                  NaN        NaN        NaN         NaN         NaN
# 5591                  NaN        NaN        NaN         NaN         NaN
# 5592                  NaN        NaN        NaN         NaN         NaN
# 5593                  NaN        NaN        NaN         NaN         NaN
# 5594                  NaN        NaN        NaN         NaN         NaN
#
#       Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0            NaN         NaN          NaN          NaN          NaN
# 1            NaN         NaN          NaN          NaN          NaN
# 2            NaN         NaN          NaN          NaN          NaN
# 3            NaN         NaN          NaN          NaN          NaN
# 4            NaN         NaN          NaN          NaN          NaN
# ...          ...         ...          ...          ...          ...
# 5590         NaN         NaN          NaN          NaN          NaN
# 5591         NaN         NaN          NaN          NaN          NaN
# 5592         NaN         NaN          NaN          NaN          NaN
# 5593         NaN         NaN          NaN          NaN          NaN
# 5594         NaN         NaN          NaN          NaN          NaN
#
#       Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16
# 0             NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...
# 5590          NaN          NaN          NaN          NaN
# 5591          NaN          NaN          NaN          NaN
# 5592          NaN          NaN          NaN          NaN
# 5593          NaN          NaN          NaN          NaN
# 5594          NaN          NaN          NaN          NaN
#
# [5595 rows x 17 columns]
