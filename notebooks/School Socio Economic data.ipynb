# %%
import pandas as pd

# %%
df = pd.read_csv('../transformed_data/school_data.csv')

# %%
df.head(20)
# Out:
#      Ano  Código_IBGE Localização  Aprovação  Reprovação  Abandono Matrículas  \
# 0   2008      1100064       Rural       77.7        22.0       0.3        328
# 1   2008      1100114       Rural       72.2        12.8      15.0        506
# 2   2008      1100122       Rural       93.3         2.1       4.6        245
# 3   2008      1100148       Rural       85.8         0.9      13.3        237
# 4   2008      1100205       Rural       72.1         7.2      20.7        598
# 5   2008      1100254       Rural       66.7        14.4      18.9        155
# 6   2008      1100338       Rural       63.0        10.4      26.6        204
# 7   2008      1101476       Rural       79.5         6.4      14.1         80
# 8   2008      1101492       Rural       82.4        11.3       6.3        247
# 9   2008      1200013       Rural       86.3         1.3      12.4         91
# 10  2008      1200138       Rural       75.3         0.0      24.7         73
# ...

# %%
df1 = pd.read_csv('../transformed_data/socioeconomicdata_updated.csv')
# Out:
# /var/folders/gv/f16by0jn2f57ngs9588479180000gn/T/ipykernel_44519/3797260506.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('../transformed_data/socioeconomicdata_updated.csv')

# %%
df1.head(20)
# Out:
#      Ano        Regiao  Código UF  UF  Código_IBGE              Municipio  \
# 0   2008  CENTRO-OESTE       53.0  DF    5300108.0               BRASILIA
# 1   2008  CENTRO-OESTE       52.0  GO    5200050.0        ABADIA DE GOIAS
# 2   2008  CENTRO-OESTE       52.0  GO    5200100.0              ABADIANIA
# 3   2008  CENTRO-OESTE       52.0  GO    5200134.0                ACREUNA
# 4   2008  CENTRO-OESTE       52.0  GO    5200159.0              ADELANDIA
# 5   2008  CENTRO-OESTE       52.0  GO    5200175.0     AGUA FRIA DE GOIAS
# 6   2008  CENTRO-OESTE       52.0  GO    5200209.0             AGUA LIMPA
# 7   2008  CENTRO-OESTE       52.0  GO    5200258.0  AGUAS LINDAS DE GOIAS
# 8   2008  CENTRO-OESTE       52.0  GO    5200308.0               ALEXANIA
# 9   2008  CENTRO-OESTE       52.0  GO    5200506.0               ALOANDIA
# 10  2008  CENTRO-OESTE       52.0  GO    5200555.0         ALTO HORIZONTE
# 11  2008  CENTRO-OESTE       52.0  GO    5200605.0  ALTO PARAISO DE GOIAS
# ...

# %%
resultado = pd.merge(df, df1, on=['Ano', 'Código_IBGE'])

# %%
resultado.head(20)
# Out:
#      Ano  Código_IBGE Localização  Aprovação  Reprovação  Abandono Matrículas  \
# 0   2008      1100064       Rural       77.7        22.0       0.3        328
# 1   2008      1100064      Urbana       85.0        11.4       3.6        781
# 2   2008      1100114       Rural       72.2        12.8      15.0        506
# 3   2008      1100114      Urbana       71.3        15.4      13.3       1884
# 4   2008      1100122       Rural       93.3         2.1       4.6        245
# 5   2008      1100122      Urbana       70.0        16.4      13.6       4087
# 6   2008      1100148       Rural       85.8         0.9      13.3        237
# 7   2008      1100148      Urbana       64.5         9.9      25.6        789
# 8   2008      1100205       Rural       72.1         7.2      20.7        598
# 9   2008      1100205      Urbana       70.8        19.8       9.4       9974
# 10  2008      1100254       Rural       66.7        14.4      18.9        155
# ...

# %%
resultado.info
# Out:
# <bound method DataFrame.info of          Ano  Código_IBGE Localização  Aprovação  Reprovação  Abandono  \
# 0       2008      1100064       Rural       77.7        22.0       0.3
# 1       2008      1100064      Urbana       85.0        11.4       3.6
# 2       2008      1100114       Rural       72.2        12.8      15.0
# 3       2008      1100114      Urbana       71.3        15.4      13.3
# 4       2008      1100122       Rural       93.3         2.1       4.6
# ...      ...          ...         ...        ...         ...       ...
# 108133  2022      5221858      Urbana       97.0         2.2       0.8
# 108134  2022      5221908      Urbana      100.0         0.0       0.0
# 108135  2022      5222005      Urbana       99.2         0.8       0.0
# 108136  2022      5222054      Urbana       99.3         0.7       0.0
# 108137  2022      5222203      Urbana      100.0         0.0       0.0
#
#        Matrículas Docentes  Estabelecimentos Turmas  ...  UF  \
# ...

# %%
file_path = '../transformed_data/school_socioeconomicdata.csv'
resultado.to_csv(file_path, index=False)
