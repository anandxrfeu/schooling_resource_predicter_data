# %% [markdown]
# MALNUTRITION IN ADOLESCENT

# %% [markdown]
# VISIT: https://sisaps.saude.gov.br/sisvan/relatoriopublico/index

# %% [markdown]
# Steps:
#
# 1 - Access the year of your choice and filter by the desired age range.
#
# 2 - Clear the data for the chosen year and convert it to a CSV file.
#
# 3 - Finally, group the data to create a malnutrition dataset with all the chosen years.

# %%
import pandas as pd

malnutrition1 = pd.read_csv('../raw_data/Desnutrição/Desnutricao 2008.csv', sep=";", encoding="utf-8")

# %%
malnutrition2 = pd.read_csv('../raw_data/Desnutrição/Desnutricao 2009.csv', sep=";", encoding="utf-8")

# %%
malnutrition1.head()
# Out:
#     Ano        Região  Código UF  UF  Código_IBGE        Municipio  \
# 0  2008  CENTRO-OESTE         53  DF       530010         BRASILIA
# 1  2008  CENTRO-OESTE         52  GO       520005  ABADIA DE GOIAS
# 2  2008  CENTRO-OESTE         52  GO       520010        ABADIANIA
# 3  2008  CENTRO-OESTE         52  GO       520013          ACREUNA
# 4  2008  CENTRO-OESTE         52  GO       520015        ADELANDIA
#
#    Magreza Acentuada Magreza Acentuada %  Magreza Magreza %  Eutrofia  \
# 0                107               1.69%      229     3.62%       4.9
# 1                  2               2.33%        5     5.81%      60.0
# 2                  4               1.15%       10     2.87%     268.0
# 3                  0                   -        1     0.97%      81.0
# 4                  0                   -        1     1.23%      70.0
#
#   Eutofia %  Sobrepeso Soprepeso %  Obesidade Obesidade %  Obesidade Grave  \
# 0    77.56%      818.0      12.95%        210       3.32%               54
# 1    69.77%       13.0      15.12%          6       6.98%                0
# 2    76.79%       47.0      13.47%         19       5.44%                1
# 3    78.64%       15.0      14.56%          6       5.83%                0
# 4    86.42%        7.0       8.64%          3        3.7%                0
#
#   Obesidade Grave %    Total
# 0             0.85%    6.318
# 1                 -   86.000
# 2             0.29%  349.000
# 3                 -  103.000
# 4                 -   81.000

# %%
malnutrition1.columns
# Out:
# Index(['Ano', 'Região', 'Código UF', 'UF', 'Código_IBGE', 'Municipio',
#        'Magreza Acentuada', 'Magreza Acentuada %', 'Magreza', 'Magreza %',
#        'Eutrofia', 'Eutofia %', 'Sobrepeso', 'Soprepeso %', 'Obesidade',
#        'Obesidade %', 'Obesidade Grave', 'Obesidade Grave %', 'Total'],
#       dtype='object')

# %%
malnutrition1.head()
# Out:
#     Ano        Região  Código UF  UF  Código_IBGE        Municipio  \
# 0  2008  CENTRO-OESTE         53  DF       530010         BRASILIA
# 1  2008  CENTRO-OESTE         52  GO       520005  ABADIA DE GOIAS
# 2  2008  CENTRO-OESTE         52  GO       520010        ABADIANIA
# 3  2008  CENTRO-OESTE         52  GO       520013          ACREUNA
# 4  2008  CENTRO-OESTE         52  GO       520015        ADELANDIA
#
#    Magreza Acentuada Magreza Acentuada %  Magreza Magreza %  Eutrofia  \
# 0                107               1.69%      229     3.62%       4.9
# 1                  2               2.33%        5     5.81%      60.0
# 2                  4               1.15%       10     2.87%     268.0
# 3                  0                   -        1     0.97%      81.0
# 4                  0                   -        1     1.23%      70.0
#
#   Eutofia %  Sobrepeso Soprepeso %  Obesidade Obesidade %  Obesidade Grave  \
# 0    77.56%      818.0      12.95%        210       3.32%               54
# 1    69.77%       13.0      15.12%          6       6.98%                0
# 2    76.79%       47.0      13.47%         19       5.44%                1
# 3    78.64%       15.0      14.56%          6       5.83%                0
# 4    86.42%        7.0       8.64%          3        3.7%                0
#
#   Obesidade Grave %    Total
# 0             0.85%    6.318
# 1                 -   86.000
# 2             0.29%  349.000
# 3                 -  103.000
# 4                 -   81.000

# %%
malnutrition2.head()
# Out:
#     Ano        Região  Código UF  UF  Código_IBGE        Municipio  \
# 0  2009  CENTRO-OESTE         53  DF       530010         BRASILIA
# 1  2009  CENTRO-OESTE         52  GO       520005  ABADIA DE GOIAS
# 2  2009  CENTRO-OESTE         52  GO       520010        ABADIANIA
# 3  2009  CENTRO-OESTE         52  GO       520013          ACREUNA
# 4  2009  CENTRO-OESTE         52  GO       520015        ADELANDIA
#
#    Magreza Acentuada Magreza Acentuada %  Magreza Magreza %  Eutrofia  \
# 0                 55               1.22%      139     3.08%     3.464
# 1                  1               1.32%        1     1.32%    59.000
# 2                  0                   -        8     3.72%   177.000
# 3                  3               0.61%       16     3.27%   346.000
# 4                  0                   -        1     1.92%    44.000
#
#   Eutofia %  Sobrepeso Soprepeso %  Obesidade Obesidade %  Obesidade Grave  \
# 0    76.76%      593.0      13.14%        226       5.01%               36
# 1    77.63%        9.0      11.84%          5       6.58%                1
# 2    82.33%       25.0      11.63%          5       2.33%                0
# 3    70.61%       85.0      17.35%         27       5.51%               13
# 4    84.62%        3.0       5.77%          4       7.69%                0
#
#   Obesidade Grave %    Total
# 0              0.8%    4.513
# 1             1.32%   76.000
# 2                 -  215.000
# 3             2.65%  490.000
# 4                 -   52.000

# %%
# List of file paths to your CSV files
file_paths = [
    "../raw_data/Desnutrição/Desnutricao 2008.csv"
    "../raw_data/Desnutrição/Desnutricao 2009.csv"
    "../raw_data/Desnutrição/Desnutricao 2010.csv"
    "../raw_data/Desnutrição/Desnutricao 2011.csv"
    "../raw_data/Desnutrição/Desnutricao 2012.csv"
    "../raw_data/Desnutrição/Desnutricao 2013.csv"
    "../raw_data/Desnutrição/Desnutricao 2014.csv"
    "../raw_data/Desnutrição/Desnutricao 2015.csv"
    "../raw_data/Desnutrição/Desnutricao 2016.csv"
    "../raw_data/Desnutrição/Desnutricao 2017.csv"
    "../raw_data/Desnutrição/Desnutricao 2018.csv"
    "../raw_data/Desnutrição/Desnutricao 2019.csv"
    "../raw_data/Desnutrição/Desnutricao 2020.csv"
    "../raw_data/Desnutrição/Desnutricao 2021.csv"
    "../raw_data/Desnutrição/Desnutricao 2022.csv"
    "../raw_data/Desnutrição/Desnutricao 2023.csv"

]

# %%
# Read each CSV and store in a list of DataFrames
dfs = [pd.read_csv(file_path) for file_path in file_paths]

# Concatenate all DataFrames together
combined_df = pd.concat(dfs, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Read each CSV and store in a list of DataFrames
# ----> 2 dfs = [pd.read_csv(file_path) for file_path in file_paths]
#       4 # Concatenate all DataFrames together
#       5 combined_df = pd.concat(dfs, ignore_index=True)
#
# Cell In[25], line 2, in <listcomp>(.0)
#       1 # Read each CSV and store in a list of DataFrames
# ----> 2 dfs = [pd.read_csv(file_path) for file_path in file_paths]
#       4 # Concatenate all DataFrames together
#       5 combined_df = pd.concat(dfs, ignore_index=True)
#
# File ~/.pyenv/versions/3.10.6/envs/schooling_resource_predicter/lib/python3.10/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.10.6/envs/schooling_resource_predicter/lib/python3.10/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/.pyenv/versions/3.10.6/envs/schooling_resource_predicter/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/.pyenv/versions/3.10.6/envs/schooling_resource_predicter/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/.pyenv/versions/3.10.6/envs/schooling_resource_predicter/lib/python3.10/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../raw_data/Desnutrição/Desnutricao 2008.csv../raw_data/Desnutrição/Desnutricao 2009.csv../raw_data/Desnutrição/Desnutricao 2010.csv../raw_data/Desnutrição/Desnutricao 2011.csv../raw_data/Desnutrição/Desnutricao 2012.csv../raw_data/Desnutrição/Desnutricao 2013.csv../raw_data/Desnutrição/Desnutricao 2014.csv../raw_data/Desnutrição/Desnutricao 2015.csv../raw_data/Desnutrição/Desnutricao 2016.csv../raw_data/Desnutrição/Desnutricao 2017.csv../raw_data/Desnutrição/Desnutricao 2018.csv../raw_data/Desnutrição/Desnutricao 2019.csv../raw_data/Desnutrição/Desnutricao 2020.csv../raw_data/Desnutrição/Desnutricao 2021.csv../raw_data/Desnutrição/Desnutricao 2022.csv../raw_data/Desnutrição/Desnutricao 2023.csv'
