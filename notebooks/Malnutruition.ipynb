# %% [markdown]
# MALNUTRITION IN ADOLESCENT

# %% [markdown]
# VISIT: https://sisaps.saude.gov.br/sisvan/relatoriopublico/index

# %% [markdown]
# Steps:
#
# 1 - Access the year of your choice and filter by the desired age range.
#
# 2 - Clear the data for the chosen year and convert it to a CSV file.
#
# 3 - Finally, group the data to create a malnutrition dataset with all the chosen years.

# %%
import pandas as pd

malnutrition1 = pd.read_csv('/Users/guilhermefraga/code/Desnutrição/Desnutricao Adolescentes 2008.csv', sep=";", encoding="utf-8")

# %%
malnutrition2 = pd.read_csv('/Users/guilhermefraga/code/Desnutrição/Desnutricao Adolescentes 2009.csv', sep=';', encoding='utf-8')

# %%
malnutrition1.head()
# Out:
#     Ano        Região  CODIGO UF  UF        Municipio  Magreza Acentuada  \
# 0  2008  CENTRO-OESTE         53  DF         BRASILIA                107
# 1  2008  CENTRO-OESTE         52  GO  ABADIA DE GOIAS                  2
# 2  2008  CENTRO-OESTE         52  GO        ABADIANIA                  4
# 3  2008  CENTRO-OESTE         52  GO          ACREUNA                  0
# 4  2008  CENTRO-OESTE         52  GO        ADELANDIA                  0
#
#   Magreza Acentuada %  Magreza Magreza %  Eutrofia Eutofia %  Sobrepeso  \
# 0               1.69%      229     3.62%       4.9    77.56%      818.0
# 1               2.33%        5     5.81%      60.0    69.77%       13.0
# 2               1.15%       10     2.87%     268.0    76.79%       47.0
# 3                   -        1     0.97%      81.0    78.64%       15.0
# 4                   -        1     1.23%      70.0    86.42%        7.0
#
#   Soprepeso %  Obesidade Obesidade %  Obesidade Grave Obesidade Grave %  \
# 0      12.95%        210       3.32%               54             0.85%
# 1      15.12%          6       6.98%                0                 -
# 2      13.47%         19       5.44%                1             0.29%
# 3      14.56%          6       5.83%                0                 -
# 4       8.64%          3        3.7%                0                 -
#
#      Total
# 0    6.318
# 1   86.000
# 2  349.000
# 3  103.000
# 4   81.000

# %%
malnutrition1.columns
# Out:
# Index(['Ano', 'Região', 'CODIGO UF', 'UF', 'Municipio', 'Magreza Acentuada',
#        'Magreza Acentuada %', 'Magreza', 'Magreza %', 'Eutrofia', 'Eutofia %',
#        'Sobrepeso', 'Soprepeso %', 'Obesidade', 'Obesidade %',
#        'Obesidade Grave', 'Obesidade Grave %', 'Total'],
#       dtype='object')

# %%
malnutrition1.head()
# Out:
#     Ano        Região  CODIGO UF  UF        Municipio  Magreza Acentuada  \
# 0  2008  CENTRO-OESTE         53  DF         BRASILIA                107
# 1  2008  CENTRO-OESTE         52  GO  ABADIA DE GOIAS                  2
# 2  2008  CENTRO-OESTE         52  GO        ABADIANIA                  4
# 3  2008  CENTRO-OESTE         52  GO          ACREUNA                  0
# 4  2008  CENTRO-OESTE         52  GO        ADELANDIA                  0
#
#   Magreza Acentuada %  Magreza Magreza %  Eutrofia Eutofia %  Sobrepeso  \
# 0               1.69%      229     3.62%       4.9    77.56%      818.0
# 1               2.33%        5     5.81%      60.0    69.77%       13.0
# 2               1.15%       10     2.87%     268.0    76.79%       47.0
# 3                   -        1     0.97%      81.0    78.64%       15.0
# 4                   -        1     1.23%      70.0    86.42%        7.0
#
#   Soprepeso %  Obesidade Obesidade %  Obesidade Grave Obesidade Grave %  \
# 0      12.95%        210       3.32%               54             0.85%
# 1      15.12%          6       6.98%                0                 -
# 2      13.47%         19       5.44%                1             0.29%
# 3      14.56%          6       5.83%                0                 -
# 4       8.64%          3        3.7%                0                 -
#
#      Total
# 0    6.318
# 1   86.000
# 2  349.000
# 3  103.000
# 4   81.000

# %%
malnutrition2.head()
# Out:
#     Ano        Região  CODIGO UF  UF        Municipio  Magreza Acentuada  \
# 0  2009  CENTRO-OESTE         53  DF         BRASILIA                 55
# 1  2009  CENTRO-OESTE         52  GO  ABADIA DE GOIAS                  1
# 2  2009  CENTRO-OESTE         52  GO        ABADIANIA                  0
# 3  2009  CENTRO-OESTE         52  GO          ACREUNA                  3
# 4  2009  CENTRO-OESTE         52  GO        ADELANDIA                  0
#
#   Magreza Acentuada %  Magreza Magreza %  Eutrofia Eutofia %  Sobrepeso  \
# 0               1.22%      139     3.08%     3.464    76.76%      593.0
# 1               1.32%        1     1.32%    59.000    77.63%        9.0
# 2                   -        8     3.72%   177.000    82.33%       25.0
# 3               0.61%       16     3.27%   346.000    70.61%       85.0
# 4                   -        1     1.92%    44.000    84.62%        3.0
#
#   Soprepeso %  Obesidade Obesidade %  Obesidade Grave Obesidade Grave %  \
# 0      13.14%        226       5.01%               36              0.8%
# 1      11.84%          5       6.58%                1             1.32%
# 2      11.63%          5       2.33%                0                 -
# 3      17.35%         27       5.51%               13             2.65%
# 4       5.77%          4       7.69%                0                 -
#
#      Total
# 0    4.513
# 1   76.000
# 2  215.000
# 3  490.000
# 4   52.000
