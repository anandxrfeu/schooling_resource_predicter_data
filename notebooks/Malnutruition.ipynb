# %% [markdown]
# MALNUTRITION IN ADOLESCENTS

# %% [markdown]
# VISIT: https://sisaps.saude.gov.br/sisvan/relatoriopublico/index

# %% [markdown]
# Steps:
#
# 1 - Access the year of your choice and filter by the desired age range.
#
# 2 - Clear the data for the chosen year and convert it to a CSV file.
#
# 3 - Finally, group the data to create a malnutrition dataset with all the chosen years.

# %%
# List of file paths to your CSV files
file_patch = [
    "../raw_data/Desnutrição/Desnutricao Adolescentes 2008.csv", 
    "../raw_data/Desnutrição/Desnutricao Adolescentes 2009.csv", 
    "../raw_data/Desnutrição/Desnutricao Adolescentes 2010.csv", 
    "../raw_data/Desnutrição/Desnutricao Adolescentes 2011.csv", 
    "../raw_data/Desnutrição/Desnutricao Adolescentes 2012.csv",
    "../raw_data/Desnutrição/Desnutricao Adolescentes 2013.csv", 
    "../raw_data/Desnutrição/Desnutricao Adolescentes 2014.csv", 
    "../raw_data/Desnutrição/Desnutricao Adolescentes 2015.csv", 
    "../raw_data/Desnutrição/Desnutricao Adolescentes 2016.csv", 
    "../raw_data/Desnutrição/Desnutricao Adolescentes 2017.csv",
    "../raw_data/Desnutrição/Desnutricao Adolescentes 2018.csv", 
    "../raw_data/Desnutrição/Desnutricao Adolescentes 2019.csv", 
    "../raw_data/Desnutrição/Desnutricao Adolescentes 2020.csv", 
    "../raw_data/Desnutrição/Desnutricao Adolescentes 2021.csv",
    "../raw_data/Desnutrição/Desnutricao Adolescentes 2022.csv",
    "../raw_data/Desnutrição/Desnutricao Adolescentes 2023.csv",

]

# %%
dfs = [pd.read_csv(file_path) for file_path in file_paths]

# Concatenate all DataFrames together
combined_df = pd.concat(dfs, ignore_index=True)


# Write the combined DataFrame to a new CSV file
#combined_df.to_csv("combined_data.csv", index=False)
file_path = "../transformed_data/cleaned_Desnutricao.csv"
combined_df.to_csv(file_path, index=False)

# %%
pd.read_csv('../transformed_data/cleaned_Desnutricao.csv', sep=';', encoding='utf-8')
# Out:
#         Ano        Região  CODIGO UF  UF        Municipio  Magreza Acentuada  \
# 0      2008  CENTRO-OESTE         53  DF         BRASILIA              107.0
# 1      2008  CENTRO-OESTE         52  GO  ABADIA DE GOIAS                2.0
# 2      2008  CENTRO-OESTE         52  GO        ABADIANIA                4.0
# 3      2008  CENTRO-OESTE         52  GO          ACREUNA                0.0
# 4      2008  CENTRO-OESTE         52  GO        ADELANDIA                0.0
# ...     ...           ...        ...  ..              ...                ...
# 89114  2023           SUL         42  SC        WITMARSUM                1.0
# 89115  2023           SUL         42  SC          XANXERE                5.0
# 89116  2023           SUL         42  SC        XAVANTINA                0.0
# 89117  2023           SUL         42  SC            XAXIM                6.0
# 89118  2023           SUL         42  SC           ZORTEA                1.0
#
# ...
